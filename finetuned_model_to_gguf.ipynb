# %% [markdown]
# **1: Install the huggingface_hub Package **

# %%
# !pip install huggingface_hub

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **2. Download a Model Snapshot from Hugging Face Hub**

# %%
from huggingface_hub import snapshot_download
model_id="karthiksagarn/Mistral-Flan-v2-finetuned"
snapshot_download(repo_id=model_id, local_dir="Mistral-Flan-v2-finetuned",
                  local_dir_use_symlinks=False, revision="main")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1194: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/664 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/560 [00:00<?, ?B/s]
# ...

# %%
# !ls -lash Mistral-Flan-v2-finetuned
# Out:
# total 14G
# 4.0K drwxr-xr-x 3 root root 4.0K Jul  8 05:45 .
# 4.0K drwxr-xr-x 1 root root 4.0K Jul  8 05:45 ..
# 4.0K -rw-r--r-- 1 root root  737 Jul  8 05:38 adapter_config.json
# 161M -rw-r--r-- 1 root root 161M Jul  8 05:38 adapter_model.safetensors
# 4.0K -rw-r--r-- 1 root root  664 Jul  8 05:38 config.json
# 4.0K -rw-r--r-- 1 root root  111 Jul  8 05:38 generation_config.json
# 4.0K -rw-r--r-- 1 root root 1.6K Jul  8 05:38 .gitattributes
# 4.0K drwxr-xr-x 3 root root 4.0K Jul  8 05:38 .huggingface
# 4.7G -rw-r--r-- 1 root root 4.7G Jul  8 05:40 model-00001-of-00003.safetensors
# 4.7G -rw-r--r-- 1 root root 4.7G Jul  8 05:40 model-00002-of-00003.safetensors
# 4.3G -rw-r--r-- 1 root root 4.3G Jul  8 05:45 model-00003-of-00003.safetensors
#  24K -rw-r--r-- 1 root root  24K Jul  8 05:38 model.safetensors.index.json
# 4.0K -rw-r--r-- 1 root root  560 Jul  8 05:38 special_tokens_map.json
# 136K -rw-r--r-- 1 root root 134K Jul  8 05:38 tokenizer_config.json
# ...

# %% [markdown]
# **3. Clone the llama.cpp Repository**

# %%
# !git clone https://github.com/ggerganov/llama.cpp.git
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 29168, done.
# remote: Counting objects: 100% (7367/7367), done.
# remote: Compressing objects: 100% (622/622), done.
# remote: Total 29168 (delta 7033), reused 6861 (delta 6734), pack-reused 21801
# Receiving objects: 100% (29168/29168), 51.05 MiB | 18.47 MiB/s, done.
# Resolving deltas: 100% (20921/20921), done.

# %%
# !pip install -r llama.cpp/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/cpu
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 36.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.8/186.8 MB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.1.99
#     Uninstalling sentencepiece-0.1.99:
#       Successfully uninstalled sentencepiece-0.1.99
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
# ...

# %%
# !python /content/llama.cpp/convert_hf_to_gguf.py -h
# Out:
# usage: convert_hf_to_gguf.py [-h] [--vocab-only] [--outfile OUTFILE]
#                              [--outtype {f32,f16,bf16,q8_0,auto}] [--bigendian] [--use-temp-file]
#                              [--no-lazy] [--model-name MODEL_NAME] [--verbose]
#                              [--split-max-tensors SPLIT_MAX_TENSORS]
#                              [--split-max-size SPLIT_MAX_SIZE] [--dry-run]
#                              [--no-tensor-first-split]
#                              model
#
# Convert a huggingface model to a GGML compatible file
#
# positional arguments:
#   model                 directory containing model file
#
# options:
#   -h, --help            show this help message and exit
#   --vocab-only          extract only the vocab
#   --outfile OUTFILE     path to write to; default: based on input. {ftype} will be replaced by the
#                         outtype.
#   --outtype {f32,f16,bf16,q8_0,auto}
# ...

# %% [markdown]
# **4.Convert the Hugging Face Model to GGUF Format**

# %%
# !python /content/llama.cpp/convert_hf_to_gguf.py Mistral-Flan-v2-finetuned \
  --outfile Mistral-Flan-v2-finetuned.gguf \
  --outtype q8_0 ## quantization q8_0 - 8bit , q4_0 - 4 bit
# Out:
# INFO:hf-to-gguf:Loading model: Mistral-Flan-v2-finetuned
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Set model parameters
# INFO:hf-to-gguf:gguf: context length = 32768
# INFO:hf-to-gguf:gguf: embedding length = 4096
# INFO:hf-to-gguf:gguf: feed forward length = 14336
# INFO:hf-to-gguf:gguf: head count = 32
# INFO:hf-to-gguf:gguf: key-value head count = 8
# INFO:hf-to-gguf:gguf: rope theta = 1000000.0
# INFO:hf-to-gguf:gguf: rms norm epsilon = 1e-05
# INFO:hf-to-gguf:gguf: file type = 7
# INFO:hf-to-gguf:Set model tokenizer
# INFO:gguf.vocab:Setting special token type bos to 1
# INFO:gguf.vocab:Setting special token type eos to 2
# INFO:gguf.vocab:Setting special token type unk to 0
# INFO:gguf.vocab:Setting special token type pad to 770
# INFO:gguf.vocab:Setting add_bos_token to True
# INFO:gguf.vocab:Setting add_eos_token to False
# INFO:hf-to-gguf:Exporting model...
# ...

# %%
# !ls -lash Mistral-Flan-v2-finetuned.gguf
# Out:
# 7.2G -rw-r--r-- 1 root root 7.2G Jul  8 05:51 Mistral-Flan-v2-finetuned.gguf

# %% [markdown]
# **5.Pushing the model a Repository on Hugging Face Hub and Upload the GGUF Model**

# %%
from huggingface_hub import HfApi
import os

# Set the token as an environment variable (recommended for security)
os.environ["HUGGING_FACE_HUB_TOKEN"] = "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"

api = HfApi()
#change your-own-account/Indic-gemma-2b-finetuned-sft-Navarasa-2.0.gguf

model_id = "karthiksagarn/Mistral-Flan-v2-finetuned.gguf"
api.create_repo(model_id, exist_ok=True, repo_type="model") # Use the api object to create the repo
api.upload_file(
    path_or_fileobj="Mistral-Flan-v2-finetuned.gguf",
    path_in_repo="Mistral-Flan-v2-finetuned.gguf",
    repo_id=model_id,
)
# Out:
# Mistral-Flan-v2-finetuned.gguf:   0%|          | 0.00/7.70G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/karthiksagarn/Mistral-Flan-v2-finetuned.gguf/commit/7551e62991ae648c0b68df7f8237b4295869b3c0', commit_message='Upload Mistral-Flan-v2-finetuned.gguf with huggingface_hub', commit_description='', oid='7551e62991ae648c0b68df7f8237b4295869b3c0', pr_url=None, pr_revision=None, pr_num=None)
